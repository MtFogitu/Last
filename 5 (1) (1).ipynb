# %% [markdown]
# # Шаг 1. Импортируйте необходимые библиотеки

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Шаг 2. Импортируйте набор данных с этого [адреса](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"

# %% [markdown]
# # Шаг 3. Сохраните его в переменной с именем users. Укажите в качестве разделителя символ | при загрузке.

# %%
user = pd.read_csv(url)

# %% [markdown]
# # Шаг 4. Выведите средний возраст по профессии

# %% [markdown]
# # Шаг 5.  Выведите доли мужчин по профессиям и отсортируйте по убыванию.

# %% [markdown]
# # Шаг 6. Для каждой профессиии вычислить минимальный и максимальный возраст

# %% [markdown]
# # Шаг 7.  Для всех комбинаций профессии и пола вычислить средний возраст

# %% [markdown]
# # Шаг 8.  Для каждой профессии вывести в процентах доли женщин и мужчин
